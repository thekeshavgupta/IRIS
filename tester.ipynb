# %%
import pandas as pd

# %%
data = pd.read_csv('relevance_test_data_with_predictions.csv')
data = data[['question', 'long_answers', 'relevance_label', 'predicted_relevance_score']]

# %%
data.head(10)
# Out:
#                                  question  \
# 0  what is the song wide open space about
# 1  what is the song wide open space about
# 2  what is the song wide open space about
# 3  what is the song wide open space about
# 4  what is the song wide open space about
# 5  what is the song wide open space about
# 6  what is the song wide open space about
# 7  what is the song wide open space about
# 8  what is the song wide open space about
# 9  what is the song wide open space about
#
#                                         long_answers  relevance_label  \
# 0  amarillo texas - based susan gibson wrote the ...                1
# 1  ready player one premiered at south by southwe...                0
# 2  set i in the nineteenth dynasty founded a temp...                0
# 3  it is estimated that the population of the wor...                0
# 4  while the specific nucleotide sequence of an m...                0
# 5  the crimean war french  guerra de crimée  russ...                0
# ...
